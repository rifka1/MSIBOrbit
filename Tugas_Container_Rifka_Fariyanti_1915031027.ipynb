# %% [markdown]
# <a href="https://colab.research.google.com/github/rifka1/MSIBOrbit/blob/main/Tugas_Container_Rifka_Fariyanti_1915031027.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Tugas Container
# Nama: Rifka Fariyanti
#
# NPM: 1915031027

# %% [markdown]
# ![dictionary.png](data:image/png;base64,...)
#
# 1. Simpan data pada tabel diatas dalam sebuah dictionary! Lalu cetak dictionary yang sudah dibuat!

# %%
data = {'NIK':[1990022, 2001077, 2002019, 2002081, 2005099, 2006003, 2006104, 2008160 ],
        'Nama':('Herman','Badar','Clara','Rista','Riani','Afif','Riven','Endah'),
        'Jenis Kelamin': ('L','L','P','P','P','L','L','P'),
        'Alamat':('Tanggerang','Bekasi','Depok','Bogor','Bekasi','Karawang','Tanggerang','Jakarta'),
        'Divisi':('Machinery','Machinery','Compressor','QC','QC','Compressor','Compressor','Machinery'),
        'Jabatan':('Manager','Staff','Staff','Staff','Operator','Operator','Operator','Operator'),
        'Gaji Pokok':('10.000.000', '7.500.000', '7.000.000', '6.500.000', '6.000.000', '5.500.000', '5.500.000', '5.000.000')}
print(data)
type(data)
data.items()
# Out:
# {'NIK': [1990022, 2001077, 2002019, 2002081, 2005099, 2006003, 2006104, 2008160], 'Nama': ('Herman', 'Badar', 'Clara', 'Rista', 'Riani', 'Afif', 'Riven', 'Endah'), 'Jenis Kelamin': ('L', 'L', 'P', 'P', 'P', 'L', 'L', 'P'), 'Alamat': ('Tanggerang', 'Bekasi', 'Depok', 'Bogor', 'Bekasi', 'Karawang', 'Tanggerang', 'Jakarta'), 'Divisi': ('Machinery', 'Machinery', 'Compressor', 'QC', 'QC', 'Compressor', 'Compressor', 'Machinery'), 'Jabatan': ('Manager', 'Staff', 'Staff', 'Staff', 'Operator', 'Operator', 'Operator', 'Operator'), 'Gaji Pokok': ('10.000.000', '7.500.000', '7.000.000', '6.500.000', '6.000.000', '5.500.000', '5.500.000', '5.000.000')}
# ...

# %% [markdown]
# 2. Buat sebuah array dengan elemen seperti gambar di bawah! Kemudian lakukan slicing pada array tersebut sesuai dengan arahan kotak merah!
#
# ![array 2.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
A = np.array([[1, 2],
              [4, 5],
              [7, 8]])
print("A = ")
print(A, '\n')

print("setelah di slicing :")

print(A[2:, 0:2],'\n')
# Out:
# A =
# [[1 2]
#  [4 5]
#  [7 8]]
#
# setelah di slicing :
# [[7 8]]

# %% [markdown]
# 3. Buat sebuah array dengan elemen seperti gambar di bawah! Kemudian lakukan slicing pada array tersebut sesuai dengan arahan kotak merah!
#
# ![array 3.png](data:image/png;base64,...)

# %%
B = np.array([[1, 6, 9],
              [2, 5, 8],])
print("B = ")
print(B, '\n')

print("setelah di slicing :")

print(B[0:3, 1:2],'\n')
# Out:
# B =
# [[1 6 9]
#  [2 5 8]]
#
# setelah di slicing :
# [[6]
#  [5]]

# %% [markdown]
# 4. Buat sebuah array dengan elemen seperti gambar di bawah! Kemudian lakukan slicing pada array tersebut sesuai dengan arahan kotak merah!
#
# ![array 4.png](data:image/png;base64,...)

# %%
#a
A = np.array([[4, 3, 8],
              [7, 2, 5],
              [6, 1, 9]])
print("A = ")
print(A, '\n')

print("setelah di slicing :")

print(A[1:3, 1:2],'\n')


#b
B = np.array([[4, 3, 8],
              [7, 2, 5],
              [6, 1, 9]])
print("B = ")
print(B, '\n')

print("setelah di slicing :")

print(B[0, 1:3],'\n')
# Out:
# A =
# [[4 3 8]
#  [7 2 5]
#  [6 1 9]]
#
# setelah di slicing :
# [[2]
#  [1]]
#
# B =
# [[4 3 8]
#  [7 2 5]
#  [6 1 9]]
#
# setelah di slicing :
# [3 8]

# %% [markdown]
# 5. Buat sebuah array dengan elemen seperti gambar di bawah! Kemudian lakukan slicing pada array tersebut sesuai dengan arahan kotak merah!
#
# ![array 5.png](data:image/png;base64,...)

# %%
#a
A = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("A = ")
print(A, '\n')

print("setelah di slicing :")

print(A[1, 1:4],'\n')

#b
B = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("B = ")
print(B, '\n')

print("setelah di slicing :")

print(B[2:4, 1:3],'\n')

#c
C = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("C = ")
print(C, '\n')

print("setelah di slicing :")

print(C[1:4, 1:4],'\n')

#d
D = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("D = ")
print(D, '\n')

print("setelah di slicing :")

print(D[1:3, 0:2],'\n')

#e
E = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("E = ")
print(E, '\n')

print("setelah di slicing :")

print(E[0:2, 0:3],'\n')

#f
F = np.array([[23, 35, 93, 87],
              [92, 44, 11, 83],
              [40, 12, 46, 28],
              [73, 67, 65, 32]])
print("F = ")
print(F, '\n')

print("setelah di slicing :")

print(F[1:4, 1:2],'\n')
# Out:
# A =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [44 11 83]
#
# B =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [[12 46]
#  [67 65]]
#
# C =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [[44 11 83]
#  [12 46 28]
#  [67 65 32]]
#
# D =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [[92 44]
#  [40 12]]
#
# E =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [[23 35 93]
#  [92 44 11]]
#
# F =
# [[23 35 93 87]
#  [92 44 11 83]
#  [40 12 46 28]
#  [73 67 65 32]]
#
# setelah di slicing :
# [[44]
#  [12]
#  [67]]
