# %% [markdown]
# <a href="https://colab.research.google.com/github/rifka1/MSIBOrbit/blob/main/Exercise_Handling_AI_Source_of_Power_Rifka_Fariyanti_1915031027.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise Handling AI Source of Power
# Nama: Rifka Fariyanti
#
# NPM: 1915031027

# %% [markdown]
# ## Latihan 1 (menulis file)
#
# 1. Buat folder baru bernama 'latihan'.
# 2. Buat file baru dalam folder 'latihan' bernama '*my favorite quote.txt*'.
# 3. Write file tersebut dengan kutipan/quote yang sangat kalian sukai.
# 4. Read file yang sudah kalian write.

# %%
file = open('/content/latihan/my favorite quote.txt', 'w+')
file.seek(0)
file.write('hati-hati dijalan')
file.close()

# %%
file = open('/content/latihan/my favorite quote.txt', 'r+')
print(file.read())
file.close()
# Out:
# hati-hati dijalan

# %% [markdown]
# ## Latihan 2
#
# 1. Read file CSV dari link ini  https://ngodingdata.com/wp-content/uploads/2020/05/titanic.csv kemudian load dalam DataFrame.
#
# 2. Buat DataFrame baru (DataFrame II) yang hanya berisi kolom 'Survived', 'Pclass', dan 'Age' saja.
#
# 3. Ambil seluruh data dari DataFrame II yang Age > 25, kemudian simpan dalam DataFrame baru (DataFrame III).
#
# 4. Simpan DataFrame III di folder 'latihan' dengan nama 'latihan2.csv'.

# %%
import pandas as pd
data_titanic = pd.read_csv('/content/titanic.csv')
data_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data_2 = data_titanic[['Survived', 'Pclass', 'Age']]
data_2.head()
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0

# %%
data_3 = data_2[data_2['Age'] > 25]
data_3.head()
# Out:
#    Survived  Pclass   Age
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0
# 6         0       1  54.0

# %%
data_3.to_csv('latihan/latihan2.csv', index = False)

# %% [markdown]
# ## Latihan 3
#
# 1. Cari image apapun di internet.
# 2. Read dan tampilkan image.
# 3. Cari tahu ukuran tensor-nya.
# 4. Lakukan operasi aritmatika apapun pada image.
# 5. Tampilkan image hasil operasi aritmatika.
# 6. Simpan image hasil operasi aritmatika dalam folder 'latihan' dengan nama 'latihan3.png'

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img_daisy = cv2.imread('daisy.jpg')
cv2_imshow(img_daisy)
# Out:
# <PIL.Image.Image image mode=RGB size=715x471 at 0x7F18648C61D0>

# %%
print(img_daisy)
# Out:
# [[[  2 212 248]
#   [  4 214 250]
#   [  5 216 253]
#   ...
#   [  6 212 253]
#   [  6 212 253]
#   [ 10 212 251]]
#
#  [[  1 211 247]
#   [  2 212 248]
#   [  5 214 252]
#   ...
#   [  5 214 254]
#   [  7 213 254]
#   [  9 214 252]]
#
#  [[  2 210 246]
#   [  2 212 248]
#   [  3 212 250]
#   ...
#   [  5 214 254]
#   [  7 213 254]
#   [  9 213 254]]
#
#  ...
#
#  [[ 40 209 237]
#   [ 39 203 232]
#   [ 44 200 229]
#   ...
#   [ 94 106  86]
#   [ 94 106  86]
#   [ 95 105  88]]
#
#  [[ 20 206 236]
#   [ 21 205 235]
#   [ 32 206 236]
#   ...
#   [ 93 105  85]
#   [ 93 105  85]
#   [ 95 105  88]]
#
#  [[  4 204 233]
#   [  7 205 234]
#   [ 20 207 238]
#   ...
#   [ 93 105  85]
#   [ 93 105  87]
#   [ 94 104  88]]]

# %%
edit_daisy = 0.5 * (img_daisy + 100)
cv2_imshow(edit_daisy)
# Out:
# <PIL.Image.Image image mode=RGB size=715x471 at 0x7F1864009690>

# %%
cv2.imwrite('hasil_edit_daisy.jpg', edit_daisy)
# Out:
# True

# %% [markdown]
# ## Latihan 4
#
# 1. Download file dari link berikut https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz kemudian simpan dalam folder 'latihan' dengan nama 'latihan4.tar.gz'
#
# 2. Extract file tersebut kemudan simpan hasil ekstrak di folder 'latihan'.

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Out:
# --2022-03-13 08:36:25--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  24.0MB/s    in 5.6s
#
# 2022-03-13 08:36:31 (14.3 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %%
# !tar -xzvf '/content/latihan4.tar.gz' -C 'latihan'
# Out:
# tar (child): /content/latihan4.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !tar -xzvf '/content/latihan44.tar.gz' -C 'sample_data'
# Out:
# Streaming output truncated to the last 5000 lines.
# aclImdb/train/unsup/44983_0.txt
# aclImdb/train/unsup/44982_0.txt
# aclImdb/train/unsup/44981_0.txt
# aclImdb/train/unsup/44980_0.txt
# aclImdb/train/unsup/44979_0.txt
# aclImdb/train/unsup/44978_0.txt
# aclImdb/train/unsup/44977_0.txt
# aclImdb/train/unsup/44976_0.txt
# aclImdb/train/unsup/44975_0.txt
# aclImdb/train/unsup/44974_0.txt
# aclImdb/train/unsup/44973_0.txt
# aclImdb/train/unsup/44972_0.txt
# aclImdb/train/unsup/44971_0.txt
# aclImdb/train/unsup/44970_0.txt
# aclImdb/train/unsup/44969_0.txt
# aclImdb/train/unsup/44968_0.txt
# aclImdb/train/unsup/44967_0.txt
# aclImdb/train/unsup/44966_0.txt
# aclImdb/train/unsup/44965_0.txt
# aclImdb/train/unsup/44964_0.txt
# aclImdb/train/unsup/44963_0.txt
# aclImdb/train/unsup/44962_0.txt
# aclImdb/train/unsup/44961_0.txt
# aclImdb/train/unsup/44960_0.txt
# aclImdb/train/unsup/44959_0.txt
# aclImdb/train/unsup/44958_0.txt
# aclImdb/train/unsup/44957_0.txt
# ...
